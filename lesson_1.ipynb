# %% [markdown]
# # Oxford International College
#
# ## Introduction to coding
#
# ### Lesson 1
#
# #### Author
#
# Oliver Sheridan-Methven.
#
# ##### Date
#
# September 2017.
#
# ##### Description
#
# Introduction to the basic containers, and a showcase of some functionality.

# %%
from IPython.display import clear_output  # If you are new to using iPython notebooks you can ignore this line.

# %% [markdown]
# The first steps in any programming language is to print the words:
# >hello world

# %%
print 'Hello world' 
# Or using a more strict syntax. 
print('Hello world')
# Out:
# Hello world
# Hello world

# %% [markdown]
# Be careful though, there is a delicate relation between the number of keystrokes and readability of your code. "*Everything should be made as simple as possible, but no simpler*" - Albert Einstein.
#
# > It is considered good practice to avoid imports such as `from numpy import *` or similar. Using such imports may cause namespace collisions, inefficient code, and can make code harder to read.

# %% [markdown]
# The above example show cases two ways output results. This has introduced the `print` function (which can be called in two different ways).
# We have also demonstrated how to do an *inline* comment. **These are extremely useful!**

# %% [markdown]
# One of the most frequent uses of python is to plot results. An example of how to plot a function would be:

# %%
import matplotlib.pylab as plt
import numpy as np
x = np.linspace(1e-4, 2*np.pi, 1000)
y = np.sin(x**2)/x
plt.plot(x, y, 'k-')
plt.show()

# %% [markdown]
# In the above example, we have introduced two new features of python: *packages* and *namespaces*.
# The two packages we have used are:
#
#  * `matplotlib`, (for plotting).
#  * `numpy`, (for numerical work in python).
#
# We have aliased `numpy` with the namespace `np`. This is common for such a well known package as numpy, and saves typing.
#
# To save even more typing we could have written:

# %%
from numpy import *
from matplotlib.pylab import plot, show
x = linspace(0, 2*pi, 1000)
y = cos(x**2)*x
plot(x, y, 'k-')
show()

# %% [markdown]
# Be careful though, there is a delicate relation between the number of keystrokes and readability of your code. "*Everything should be made as simple as possible, but no simpler*" - Albert Einstein.
#
# > It is considered good practice to avoid imports such as `from numpy import *` or similar. Using such imports may cause namespace collisions, inefficient code, and can make code harder to read.

# %%
clear_output()
